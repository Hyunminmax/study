# %%
# 단어 a의 가운데 글자 반환
# 단어의 길이가 짝수라면 가운데 두글자를 출력하라.

a = input("단어를 입력해주세요.")
a_len = len(a)
#입력값 a의 짝수 여부 판단
if a_len % 2 == 0:
    #짝수의 경우
    x = int(a_len / 2)
    print(a[x-1:x+1:])
else:
    #홀수의 경우
    x = int(a_len / 2)
    print(a[x])
# Out:
# 단어를 입력해주세요.abc
# b
