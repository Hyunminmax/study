# %%
cd /content/drive/MyDrive/InBox/OZ코딩스쿨
# Out:
# /content/drive/MyDrive/InBox/OZ코딩스쿨

# %%
f = open('text.txt', 'w')
massage = ''
for i in range(10):
    massage += '개발자 여러분\n'
f.write(massage)
f.close()

# %%
f = open('text.txt', 'r')
line = f.readline()
print(line)
f.close()
# Out:
# 개발자 여러분

# %%
f = open('text.txt', 'r')
print("a")
#line = f.readline()
while line:
    print("b")
    line = f.readline()
    print(line)
f.close()
print("c")
# Out:
# a
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
# 개발자 여러분
#
# b
#
# c

# %%
list = ['10', '20', '30', '40']

with open('test.csv', 'w') as f:
    f.write(','.join(list))
