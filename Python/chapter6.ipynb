# %%
생년월일 = "2000.12.25"
# 2000 12 25

print(f'{생년월일[0:4]} {생년월일[5:7]} {생년월일[8:10]}')
# Out:
# 2000 12 25

# %%
퀴즈 ="스님이 공중에 뜬다를 6자로 말하면? 어중이떠중이"

# 총 인덱스 크기
total_len = len(퀴즈)

# 답의 길이를 제외한 길이
answer_len = total_len - 6

# 정답인덱스 출력
print(퀴즈[answer_len:])
# Out:
# 어중이떠중이
