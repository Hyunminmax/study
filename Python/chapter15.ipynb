# %%
#문제 절대값 정수가 담긴 리스트와 그 정수들의 부호(True: 양수, False: 음수)가 담긴 리스트가 있다.
#두 리스트를 이용해 실제 정수의 합을 구하시오

정수 = [10, 5, 8]
부호 = [True, False, True]

answer = 0
for i in range(len(정수)):
    if 부호[i]:
        answer += 정수[i]
    else:
        answer -= 정수[i]
print(answer)
# Out:
# 13
